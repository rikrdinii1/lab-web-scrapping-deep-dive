# %% [markdown]
# # Advanced Web Scraping Lab
#
# In this lab you will first learn the following code snippet which is a simple web spider class that allows you to scrape paginated webpages. Read the code, run it, and make sure you understand how it work. In the challenges of this lab, we will guide you in building up this class so that eventually you will have a more robus web spider that you can further work on in the Web Scraping Project.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

class IronhackSpider:
    """
    This is the constructor class to which you can pass a bunch of parameters. 
    These parameters are stored to the class instance variables so that the
    class functions can access them later.
    
    url_pattern: the regex pattern of the web urls to scape
    pages_to_scrape: how many pages to scrape
    sleep_interval: the time interval in seconds to delay between requests. If <0, requests will not be delayed.
    content_parser: a function reference that will extract the intended info from the scraped content.
    """
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    """
    Scrape the content of a single url.
    """
    def scrape_url(self, url):
        response = requests.get(url)
        result = self.content_parser(response.content)
        self.output_results(result)
    
    def sleep_interval():
        self.sleep_interval = sleep_interval
        if sleep_interval > 0:
            time.sleep(randint(5, high = 10))

        return sleep_interval
    
    """
    Export the scraped content. Right now it simply print out the results.
    But in the future you can export the results into a text file or database.
    """
    def output_results(self, r):
        print(r)
    
    """
    After the class is instantiated, call this function to start the scraping jobs.
    This function uses a FOR loop to call `scrape_url()` for each url to scrape.
    """
    def kickstart(self):
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)


URL_PATTERN = f'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
PAGES_TO_SCRAPE = 2 # how many webpages to scrapge

"""
This is a custom parser function you will complete in the challenge.
Right now it simply returns the string passed to it. But in this lab
you will complete this function so that it extracts the quotes.
This function will be passed to the IronhackSpider class.
"""
def quotes_parser(content):
    html = requests.get(URL_PATTERN).content
    soup = BeautifulSoup(html, 'lxml')
    texto = soup.find_all('span',class_='text')
    autor = soup.find_all('small',class_='author')
    texto_limpio = [element.text.strip() for element in texto]
    autor_limpio = [element.text.strip() for element in autor]
    content = pd.DataFrame(texto_limpio, autor_limpio)

    return content

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Challenge 1 - Custom Parser Function
#
# In this challenge, complete the custom `quotes_parser()` function so that the returned result contains the quote string instead of the whole html page content.
#
# In the cell below, write your updated `quotes_parser()` function and kickstart the spider. Make sure the results being printed contain a list of quote strings extracted from the html content.

# %%
# your code here
URL_PATTERN = 'http://quotes.toscrape.com/'
def quotes_parser(content):
    html = requests.get(URL_PATTERN).content
    soup = BeautifulSoup(html, 'lxml')
    texto = soup.find_all('span',class_='text')
    autor = soup.find_all('small',class_='author')
    texto_limpio = [element.text.strip() for element in texto]
    autor_limpio = [element.text.strip() for element in autor]
    content = pd.DataFrame(texto_limpio, autor_limpio)

    return content
quotes_parser(URL_PATTERN)
# Out:
#                                                                    0
# Albert Einstein    “The world as we have created it is a process ...
# J.K. Rowling       “It is our choices, Harry, that show what we t...
# Albert Einstein    “There are only two ways to live your life. On...
# Jane Austen        “The person, be it gentleman or lady, who has ...
# Marilyn Monroe     “Imperfection is beauty, madness is genius and...
# Albert Einstein    “Try not to become a man of success. Rather be...
# André Gide         “It is better to be hated for what you are tha...
# Thomas A. Edison   “I have not failed. I've just found 10,000 way...
# Eleanor Roosevelt  “A woman is like a tea bag; you never know how...
# Steve Martin       “A day without sunshine is like, you know, nig...

# %% [markdown]
# ## Challenge 2 - Error Handling
#
# In `IronhackSpider.scrape_url()`, catch any error that might occur when you make requests to scrape the webpage. This includes checking the response status code and catching http request errors such as timeout, SSL, and too many redirects.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here

# %% [markdown]
# # Challenge 3 - Sleep Interval
#
# In `IronhackSpider.kickstart()`, implement `sleep_interval`. You will check if `self.sleep_interval` is larger than 0. If so, tell the FOR loop to sleep the given amount of time before making the next request.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

class IronhackSpider:
    
    def __init__(self, url_pattern, pages_to_scrape=10, sleep_interval=-1, content_parser=None):
        self.url_pattern = url_pattern
        self.pages_to_scrape = pages_to_scrape
        self.sleep_interval = sleep_interval
        self.content_parser = content_parser
    
    def scrape_url(self, url):
        response = requests.get(url)
        result = self.content_parser(response.content)
        self.output_results(result)
    
    def sleep_interval():
        self.sleep_interval = sleep_interval
        if sleep_interval > 0:
            time.sleep(randint(5, high = 10))

        return sleep_interval
    
    def output_results(self, r):
        print(r)
    
    
    def kickstart(self):
        for i in range(1, self.pages_to_scrape+1):
            self.scrape_url(self.url_pattern % i)


URL_PATTERN = 'http://quotes.toscrape.com/page/%s/' # regex pattern for the urls to scrape
URL_PATTERN2 = 'http://books.toscrape.com/catalogue/page-%s.html'# regex pattern for the urls to scrape

PAGES_TO_SCRAPE = 10 # how many webpages to scrapge

def quotes_parser(content_parser):
    soup = BeautifulSoup(content_parser, 'lxml')
    texto = soup.find_all('span',class_='text')
    autor = soup.find_all('small',class_='author')
    texto_limpio = [element.text.strip() for element in texto]
    autor_limpio = [element.text.strip() for element in autor]
    content = pd.DataFrame(texto_limpio, autor_limpio)
    #content = texto_limpio + autor_limpio
    
    return content

# Instantiate the IronhackSpider class
my_spider = IronhackSpider(URL_PATTERN, PAGES_TO_SCRAPE, content_parser=quotes_parser)

# Start scraping jobs
my_spider.kickstart()
# Out:
#                                                                    0
# Albert Einstein    “The world as we have created it is a process ...
# J.K. Rowling       “It is our choices, Harry, that show what we t...
# Albert Einstein    “There are only two ways to live your life. On...
# Jane Austen        “The person, be it gentleman or lady, who has ...
# Marilyn Monroe     “Imperfection is beauty, madness is genius and...
# Albert Einstein    “Try not to become a man of success. Rather be...
# André Gide         “It is better to be hated for what you are tha...
# Thomas A. Edison   “I have not failed. I've just found 10,000 way...
# Eleanor Roosevelt  “A woman is like a tea bag; you never know how...
# Steve Martin       “A day without sunshine is like, you know, nig...
#                                                                      0
# Marilyn Monroe       “This life is what you make it. No matter what...
# J.K. Rowling         “It takes a great deal of bravery to stand up ...
# Albert Einstein      “If you can't explain it to a six year old, yo...
# Bob Marley           “You may not be her first, her last, or her on...
# Dr. Seuss            “I like nonsense, it wakes up the brain cells....
# Douglas Adams        “I may not have gone where I intended to go, b...
# Elie Wiesel          “The opposite of love is not hate, it's indiff...
# Friedrich Nietzsche  “It is not a lack of love, but a lack of frien...
# Mark Twain           “Good friends, good books, and a sleepy consci...
# Allen Saunders       “Life is what happens to us while we are makin...
#                                                                      0
# Pablo Neruda         “I love you without knowing how, or when, or f...
# Ralph Waldo Emerson  “For every minute you are angry you lose sixty...
# Mother Teresa        “If you judge people, you have no time to love...
# Garrison Keillor     “Anyone who thinks sitting in church can make ...
# Jim Henson           “Beauty is in the eye of the beholder and it m...
# Dr. Seuss            “Today you are You, that is truer than true. T...
# Albert Einstein      “If you want your children to be intelligent, ...
# J.K. Rowling         “It is impossible to live without failing at s...
# Albert Einstein      “Logic will get you from A to Z; imagination w...
# Bob Marley           “One good thing about music, when it hits you,...
#                                                                    0
# Dr. Seuss          “The more that you read, the more things you w...
# J.K. Rowling       “Of course it is happening inside your head, H...
# Bob Marley         “The truth is, everyone is going to hurt you. ...
# Mother Teresa      “Not all of us can do great things. But we can...
# J.K. Rowling       “To the well-organized mind, death is but the ...
# Charles M. Schulz  “All you need is love. But a little chocolate ...
# William Nicholson                 “We read to know we're not alone.”
# Albert Einstein     “Any fool can know. The point is to understand.”
# Jorge Luis Borges  “I have always imagined that Paradise will be ...
# George Eliot       “It is never too late to be what you might hav...
#                                                                         0
# George R.R. Martin      “A reader lives a thousand lives before he die...
# C.S. Lewis              “You can never get a cup of tea large enough o...
# Marilyn Monroe          “You believe lies so you eventually learn to t...
# Marilyn Monroe          “If you can make a woman laugh, you can make h...
# Albert Einstein         “Life is like riding a bicycle. To keep your b...
# Marilyn Monroe          “The real lover is the man who can thrill you ...
# Marilyn Monroe          “A wise girl kisses but doesn't love, listens ...
# Martin Luther King Jr.      “Only in the darkness can you see the stars.”
# J.K. Rowling            “It matters not what someone is born, but what...
# James Baldwin           “Love does not begin and end the way we seem t...
#                                                                       0
# Jane Austen           “There is nothing I would not do for those who...
# Eleanor Roosevelt             “Do one thing every day that scares you.”
# Marilyn Monroe        “I am good, but not an angel. I do sin, but I ...
# Albert Einstein       “If I were not a physicist, I would probably b...
# Haruki Murakami       “If you only read the books that everyone else...
# Alexandre Dumas fils  “The difference between genius and stupidity i...
# Stephenie Meyer                      “He's like a drug for you, Bella.”
# Ernest Hemingway               “There is no friend as loyal as a book.”
# Helen Keller          “When one door of happiness closes, another op...
# George Bernard Shaw   “Life isn't about finding yourself. Life is ab...
#                                                                      0
# Charles Bukowski     “That's the problem with drinking, I thought, ...
# Suzanne Collins      “You don’t forget the face of the person who w...
# Suzanne Collins      “Remember, we're madly in love, so it's all ri...
# C.S. Lewis           “To love at all is to be vulnerable. Love anyt...
# J.R.R. Tolkien                    “Not all those who wander are lost.”
# J.K. Rowling         “Do not pity the dead, Harry. Pity the living,...
# Ernest Hemingway     “There is nothing to writing. All you do is si...
# Ralph Waldo Emerson  “Finish each day and be done with it. You have...
# Mark Twain           “I have never let my schooling interfere with ...
# Dr. Seuss            “I have heard there are troubles of more than ...
#                                                                   0
# Alfred Tennyson   “If I had a flower for every time I thought of...
# Charles Bukowski  “Some people never go crazy. What truly horrib...
# Terry Pratchett   “The trouble with having an open mind, of cour...
# Dr. Seuss         “Think left and think right and think low and ...
# J.D. Salinger     “What really knocks me out is a book that, whe...
# George Carlin     “The reason I talk to myself is because I’m th...
# John Lennon       “You may say I'm a dreamer, but I'm not the on...
# W.C. Fields       “I am free of all prejudice. I hate everyone e...
# Ayn Rand          “The question isn't who is going to let me; it...
# Mark Twain        “′Classic′ - a book which people praise and do...
#                                                                  0
# Albert Einstein  “Anyone who has never made a mistake has never...
# Jane Austen      “A lady's imagination is very rapid; it jumps ...
# J.K. Rowling     “Remember, if the time should come when you ha...
# Jane Austen      “I declare after all there is no enjoyment lik...
# Jane Austen      “There are few people whom I really love, and ...
# C.S. Lewis       “Some day you will be old enough to start read...
# C.S. Lewis       “We are not necessarily doubting that God will...
# Mark Twain       “The fear of death follows from the fear of li...
# Mark Twain       “A lie can travel half way around the world wh...
# C.S. Lewis       “I believe in Christianity as I believe that t...
#                                                                     0
# J.K. Rowling        “The truth." Dumbledore sighed. "It is a beaut...
# Jimi Hendrix        “I'm the one that's got to die when it's time ...
# J.M. Barrie                “To die will be an awfully big adventure.”
# E.E. Cummings       “It takes courage to grow up and become who yo...
# Khaled Hosseini     “But better to get hurt by the truth than comf...
# Harper Lee          “You never really understand a person until yo...
# Madeleine L'Engle   “You have to write the book that wants to be w...
# Mark Twain          “Never tell the truth to people who are not wo...
# Dr. Seuss                 “A person's a person, no matter how small.”
# George R.R. Martin  “... a mind needs books as a sword needs a whe...

# %% [markdown]
# # Challenge 4 - Test Batch Scraping
#
# Change the `PAGES_TO_SCRAPE` value from `1` to `10`. Try if your code still works as intended to scrape 10 webpages. If there are errors in your code, fix them.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
#print(URL_PATTERN)
url = URL_PATTERN
num_pagina = 2
url_nueva = url.replace('%s',str(num_pagina))
#print(url_nueva)

pages_to_scrape = 20
for i in range(1, pages_to_scrape+1):
    url = URL_PATTERN.replace('%s',str(i))

    print(url)
# Out:
# http://quotes.toscrape.com/page/1/
# http://quotes.toscrape.com/page/2/
# http://quotes.toscrape.com/page/3/
# http://quotes.toscrape.com/page/4/
# http://quotes.toscrape.com/page/5/
# http://quotes.toscrape.com/page/6/
# http://quotes.toscrape.com/page/7/
# http://quotes.toscrape.com/page/8/
# http://quotes.toscrape.com/page/9/
# http://quotes.toscrape.com/page/10/
# http://quotes.toscrape.com/page/11/
# http://quotes.toscrape.com/page/12/
# http://quotes.toscrape.com/page/13/
# http://quotes.toscrape.com/page/14/
# http://quotes.toscrape.com/page/15/
# http://quotes.toscrape.com/page/16/
# http://quotes.toscrape.com/page/17/
# http://quotes.toscrape.com/page/18/
# http://quotes.toscrape.com/page/19/
# http://quotes.toscrape.com/page/20/

# %% [markdown]
# # Challenge 5 - Scrape a Different Website
#
# Update the parameters passed to the `IronhackSpider` constructor so that you coder can crawl [books.toscrape.com](http://books.toscrape.com/). You will need to use a different `URL_PATTERN` (figure out the new url pattern by yourself) and write another parser function to be passed to `IronhackSpider`.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here

# %% [markdown]
# # Bonus Challenge 1 - Making Your Spider Unblockable
#
# Use techniques such as randomizing user agents and referers in your requests to reduce the likelihood that your spider is blocked by websites. [Here](http://blog.adnansiddiqi.me/5-strategies-to-write-unblock-able-web-scrapers-in-python/) is a great article to learn these techniques.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here

# %% [markdown]
# # Bonus Challenge 2 - Making Asynchronous Calls
#
# Implement asynchronous calls to `IronhackSpider`. You will make requests in parallel to complete your tasks faster.
#
# In the cell below, place your entire code including the updated `IronhackSpdier` class and the code to kickstart the spider.

# %%
# your code here
